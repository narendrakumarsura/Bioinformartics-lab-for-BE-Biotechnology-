# %%
# !pip install Bio
# Out:
# Collecting Bio
#   Downloading bio-1.8.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting biopython>=1.80 (from Bio)
#   Downloading biopython-1.85-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting gprofiler-official (from Bio)
#   Downloading gprofiler_official-1.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting mygene (from Bio)
#   Downloading mygene-3.2.2-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from Bio) (2.2.2)
# Requirement already satisfied: pooch in /usr/local/lib/python3.12/dist-packages (from Bio) (1.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from Bio) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from Bio) (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from biopython>=1.80->Bio) (2.0.2)
# Collecting biothings-client>=0.2.6 (from mygene->Bio)
#   Downloading biothings_client-0.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->Bio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->Bio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->Bio) (2025.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch->Bio) (4.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from pooch->Bio) (25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->Bio) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->Bio) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->Bio) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->Bio) (2025.10.5)
# Requirement already satisfied: httpx>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from biothings-client>=0.2.6->mygene->Bio) (0.28.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->Bio) (1.17.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (4.15.0)
# Downloading bio-1.8.1-py3-none-any.whl (321 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.3/321.3 kB 7.0 MB/s eta 0:00:00
# Downloading biopython-1.85-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 52.0 MB/s eta 0:00:00
# Downloading gprofiler_official-1.0.0-py3-none-any.whl (9.3 kB)
# Downloading mygene-3.2.2-py2.py3-none-any.whl (5.4 kB)
# Downloading biothings_client-0.4.1-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: biopython, gprofiler-official, biothings-client, mygene, Bio
# Successfully installed Bio-1.8.1 biopython-1.85 biothings-client-0.4.1 gprofiler-official-1.0.0 mygene-3.2.2

# %%
from Bio.Blast import NCBIWWW
from Bio.Blast import NCBIXML

# Define the two sequence IDs you want to BLAST
sequence_ids = ["PU773469.1", "PU773470.1"] # Replace with your desired sequence IDs

# Perform BLAST for each sequence
for seq_id in sequence_ids:
    print(f"Performing BLAST for sequence ID: {seq_id}")
    # Perform the BLAST search
    result_handle = NCBIWWW.qblast(
        "blastn",  # BLAST program (nucleotide blast)
        "nt",      # Database (nucleotide database)
        seq_id     # Query sequence ID
    )

    # Parse the BLAST results
    blast_records = NCBIXML.parse(result_handle)

    # Print some information about the hits
    for blast_record in blast_records:
        print(f"Query: {blast_record.query}")
        for alignment in blast_record.alignments:
            for hsp in alignment.hsps:
                print(f"  Alignment: {alignment.title}")
                print(f"  Length: {alignment.length}")
                print(f"  E-value: {hsp.expect}")
                print(f"  Query start: {hsp.query_start}, Query end: {hsp.query_end}")
                print(f"  Subject start: {hsp.sbjct_start}, Subject end: {hsp.sbjct_end}")
                print(f"  Score: {hsp.score}")
                print(f"  Identities: {hsp.identities}")
                print(f"  Gaps: {hsp.gaps}")
                print(f"  Query: {hsp.query[0:75]}...")
                print(f"  Match: {hsp.match[0:75]}...")
                print(f"  Sbjct: {hsp.sbjct[0:75]}...")
                print("-" * 80)

    result_handle.close()
# Out:
# Performing BLAST for sequence ID: PU773469.1
# Query: Sequence 35 from patent US 12098131 B2
# Performing BLAST for sequence ID: PU773470.1
# Query: Sequence 36 from patent US 12098131 B2
#   Alignment: gi|3020765241|ref|XM_075101328.1| PREDICTED: Phalacrocorax aristotelis MAF bZIP transcription factor (MAF), transcript variant X5, mRNA
#   Length: 1887
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 783, Subject end: 763
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2853416636|ref|XR_011345929.1| PREDICTED: Narcine bancroftii transcription factor Maf-like (LOC138745038), transcript variant X9, misc_RNA
#   Length: 2097
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 672, Subject end: 652
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2922217083|ref|XM_071814362.1| PREDICTED: Patagioenas fasciata MAF bZIP transcription factor (MAF), transcript variant X4, mRNA
#   Length: 1728
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 712, Subject end: 692
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2925848838|ref|XR_005268831.2| PREDICTED: Anas platyrhynchos MAF bZIP transcription factor (MAF), transcript variant X9, misc_RNA
#   Length: 2476
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 914, Subject end: 894
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2782199485|ref|XM_048068887.2| PREDICTED: Anser cygnoides MAF bZIP transcription factor (MAF), transcript variant X5, mRNA
#   Length: 2759
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 966, Subject end: 946
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2862881490|ref|XM_051847315.2| PREDICTED: Oryctolagus cuniculus MAF bZIP transcription factor (MAF), transcript variant X2, mRNA
#   Length: 10767
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 1188, Subject end: 1168
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2813378191|ref|XM_068956319.1| PREDICTED: Struthio camelus MAF bZIP transcription factor (MAF), transcript variant X1, mRNA
#   Length: 5850
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 898, Subject end: 878
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|3053561351|ref|XM_076572184.1| PREDICTED: Peromyscus maniculatus bairdii MAF bZIP transcription factor (Maf), transcript variant X2, mRNA
#   Length: 1503
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 266, Subject end: 246
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2952940301|ref|XM_072980594.1| PREDICTED: Pogona vitticeps MAF bZIP transcription factor (MAF), transcript variant X1, mRNA
#   Length: 2829
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 1539, Subject end: 1519
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2746031953|ref|XM_065925074.1| PREDICTED: Muntiacus reevesi MAF bZIP transcription factor (MAF), transcript variant X1, mRNA
#   Length: 3493
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 959, Subject end: 939
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2775598664|ref|XR_010802207.1| PREDICTED: Hoplias malabaricus MAF bZIP transcription factor b (mafb), transcript variant X2, misc_RNA
#   Length: 3255
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 1183, Subject end: 1163
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2870971002|ref|XM_024143707.2| PREDICTED: Salvelinus sp. IW2-2015 transcription factor Maf (LOC112077119), mRNA
#   Length: 1513
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 552, Subject end: 532
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|3061147504|emb|OZ310611.1| Mergellus albellus genome assembly, chromosome: 12
#   Length: 21668236
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 15684512, Subject end: 15684532
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2939278066|ref|XM_072435876.1| PREDICTED: Eucyclogobius newberryi transcription factor Maf-like (LOC140349512), transcript variant X1, mRNA
#   Length: 1919
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 730, Subject end: 710
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|3020765247|ref|XR_012661986.1| PREDICTED: Phalacrocorax aristotelis MAF bZIP transcription factor (MAF), transcript variant X8, misc_RNA
#   Length: 2752
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 783, Subject end: 763
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|3034427453|emb|LR880647.2| Poecilia reticulata genome assembly, chromosome: 3
#   Length: 36774752
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 21370472, Subject end: 21370492
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2862881488|ref|XM_051847314.2| PREDICTED: Oryctolagus cuniculus MAF bZIP transcription factor (MAF), transcript variant X1, mRNA
#   Length: 3974
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 1188, Subject end: 1168
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2837987609|ref|XM_069456389.1| PREDICTED: Eulemur rufifrons MAF bZIP transcription factor (MAF), mRNA
#   Length: 2093
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 911, Subject end: 891
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|3019029589|ref|XM_032768130.2| PREDICTED: Chelonoidis abingdonii MAF bZIP transcription factor (MAF), mRNA
#   Length: 2276
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 1170, Subject end: 1150
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2948313327|ref|XM_072872407.1| PREDICTED: Ciconia boyciana MAF bZIP transcription factor (MAF), transcript variant X3, mRNA
#   Length: 1871
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 790, Subject end: 770
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2993404841|ref|XM_039460639.2| PREDICTED: Saimiri boliviensis MAF bZIP transcription factor (MAF), transcript variant X1, mRNA
#   Length: 1899
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 602, Subject end: 582
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2868062739|ref|XM_070262084.1| PREDICTED: Equus caballus MAF bZIP transcription factor (MAF), transcript variant X3, mRNA
#   Length: 11629
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 224, Subject end: 204
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|3037423489|ref|XM_075977403.1| PREDICTED: Microtus pennsylvanicus MAF bZIP transcription factor (Maf), transcript variant X1, mRNA
#   Length: 2252
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 1023, Subject end: 1003
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2978652949|ref|XM_074026757.1| PREDICTED: Macaca fascicularis MAF bZIP transcription factor (MAF), transcript variant X4, mRNA
#   Length: 14744
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 191, Subject end: 171
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2797700863|ref|XM_068203082.1| PREDICTED: Anomalospiza imberbis MAF bZIP transcription factor (MAF), transcript variant X1, mRNA
#   Length: 2731
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 735, Subject end: 715
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2745954926|ref|XM_065898976.1| PREDICTED: Phocoena phocoena MAF bZIP transcription factor (MAF), mRNA
#   Length: 1875
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 233, Subject end: 213
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|3045327664|ref|XM_076265577.1| PREDICTED: Alosa pseudoharengus transcription factor Maf-like (LOC143102152), mRNA
#   Length: 2004
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 82, Subject end: 62
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2921975551|gb|CP130389.1| Cairina moschata breed yongchun chromosome 12
#   Length: 21384265
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 5902841, Subject end: 5902821
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2853416627|ref|XR_011345926.1| PREDICTED: Narcine bancroftii transcription factor Maf-like (LOC138745038), transcript variant X6, misc_RNA
#   Length: 1875
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 672, Subject end: 652
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|3017532452|emb|OZ273949.1| Turdus pilaris genome assembly, chromosome: 11
#   Length: 23719144
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 18038220, Subject end: 18038240
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2917156915|ref|XM_071567162.1| PREDICTED: Pithys albifrons albifrons MAF bZIP transcription factor (MAF), transcript variant X6, mRNA
#   Length: 1936
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 713, Subject end: 693
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2853416651|ref|XR_011345934.1| PREDICTED: Narcine bancroftii transcription factor Maf-like (LOC138745038), transcript variant X14, misc_RNA
#   Length: 1952
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 672, Subject end: 652
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2851973331|ref|XM_069738798.1| PREDICTED: Ranitomeya imitator MAF bZIP transcription factor (MAF), mRNA
#   Length: 1870
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 533, Subject end: 513
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2826374524|ref|XM_069085873.1| PREDICTED: Petaurus breviceps papuanus MAF bZIP transcription factor (MAF), transcript variant X1, mRNA
#   Length: 2475
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 227, Subject end: 207
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|3009236379|ref|XM_074912963.1| PREDICTED: Athene noctua MAF bZIP transcription factor (MAF), transcript variant X4, mRNA
#   Length: 2856
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 922, Subject end: 902
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2987547781|ref|XM_074157830.1| PREDICTED: Numenius arquata MAF bZIP transcription factor (MAF), transcript variant X1, mRNA
#   Length: 3339
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 82, Subject end: 62
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2842182351|ref|XR_011240805.1| PREDICTED: Paralichthys olivaceus MAF bZIP transcription factor a (mafa), transcript variant X6, misc_RNA
#   Length: 10978
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 903, Subject end: 883
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2813378193|ref|XM_068956320.1| PREDICTED: Struthio camelus MAF bZIP transcription factor (MAF), transcript variant X2, mRNA
#   Length: 6885
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 898, Subject end: 878
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2942556112|ref|XM_072595867.1| PREDICTED: Chiloscyllium punctatum MAF bZIP transcription factor a (mafa), transcript variant X1, mRNA
#   Length: 3842
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 806, Subject end: 786
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2853416675|ref|XR_011345942.1| PREDICTED: Narcine bancroftii transcription factor Maf-like (LOC138745038), transcript variant X22, misc_RNA
#   Length: 1932
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 672, Subject end: 652
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2775554760|ref|XM_066684828.1| PREDICTED: Hoplias malabaricus MAF bZIP transcription factor a (mafa), mRNA
#   Length: 4149
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 584, Subject end: 564
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|3062259606|ref|XM_076992527.1| PREDICTED: Brachyhypopomus gauderio MAF bZIP transcription factor a (mafa), mRNA
#   Length: 2676
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 1570, Subject end: 1550
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2775415258|ref|XM_066583747.1| PREDICTED: Eleutherodactylus coqui MAF bZIP transcription factor (MAF), mRNA
#   Length: 3277
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 451, Subject end: 431
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2789130702|ref|XM_067389028.1| PREDICTED: Chanodichthys erythropterus MAF bZIP transcription factor a (mafa), transcript variant X3, mRNA
#   Length: 2350
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 1307, Subject end: 1287
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2947213380|ref|XM_023839610.2| PREDICTED: Paramormyrops kingsleyae transcription factor Maf-like (LOC111858138), transcript variant X2, mRNA
#   Length: 8053
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 593, Subject end: 573
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|3006644026|ref|XM_074882178.1| PREDICTED: Strix uralensis MAF bZIP transcription factor (MAF), transcript variant X4, mRNA
#   Length: 2208
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 936, Subject end: 916
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|3057977203|ref|XM_076838509.1| PREDICTED: Callospermophilus lateralis MAF bZIP transcription factor (Maf), transcript variant X7, mRNA
#   Length: 1372
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 258, Subject end: 238
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2990527221|ref|XM_074282488.1| PREDICTED: Sminthopsis crassicaudata MAF bZIP transcription factor (MAF), transcript variant X1, mRNA
#   Length: 1334
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 89, Subject end: 69
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2782123750|ref|XM_067020404.1| PREDICTED: Kogia breviceps MAF bZIP transcription factor (MAF), transcript variant X3, mRNA
#   Length: 2621
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 252, Subject end: 232
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
#   Alignment: gi|2947320752|ref|XM_072731478.1| PREDICTED: Vulpes vulpes MAF bZIP transcription factor (MAF), transcript variant X3, mRNA
#   Length: 2950
#   E-value: 4.64427
#   Query start: 1, Query end: 21
#   Subject start: 339, Subject end: 319
#   Score: 42.0
#   Identities: 21
#   Gaps: 0
#   Query: TCAGATCGAAGTCATTAACAT...
#   Match: |||||||||||||||||||||...
#   Sbjct: TCAGATCGAAGTCATTAACAT...
# --------------------------------------------------------------------------------
